# %%
# Admin
class restaurent:
    def __init__(self):
        self.food={}
        self.food_id=len(self.food)+1
        self.personal_detail={}
        self.customer_id=len(self.personal_detail)+1
    
    def menu_card(self):
        self.food_name=input("enter food name   ")
        self.quantity=float(input("enter food quantity"))
        self.price=float(input("enter food price: inr "))
        self.discount= float(input("enter food discount : inr "))
        self.stock= float(input("enter your stock : pieces "))
        self.item={"name":self.food_name,"quantity":self.quantity,"price":self.price,"discount":self.discount,"stock":self.stock}
        self.food_id=len(self.food)+1
        self.food[self.food_id]=self.item
        print(self.food)
        print("item added successfully")

    def remove_menu_card(self):
        del self.food[float(input("enter the food_id which you want to delete"))]
        print("Remaing menu are",self.food)

    def edit_menu_card(self):
        f_id=float(input("enter the food_id which you want to update"))
        for i in self.food[f_id]:
            self.food[f_id][i]=input(f"Enter the {i} data you want to update :" )
        print(self.food)


x=restaurent()
x.menu_card()
x.menu_card()
x.edit_menu_card()
x.remove_menu_card()
# Out:
# enter food name   pizza
# enter food quantity1
# enter food price: inr 150
# enter food discount : inr 20
# enter your stock : pieces 25
# {1: {'name': 'pizza', 'quantity': 1.0, 'price': 150.0, 'discount': 20.0, 'stock': 25.0}}
# item added successfully
# enter food name   vada
# enter food quantity3
# enter food price: inr 42
# enter food discount : inr 8
# enter your stock : pieces 59
# {1: {'name': 'pizza', 'quantity': 1.0, 'price': 150.0, 'discount': 20.0, 'stock': 25.0}, 2: {'name': 'vada', 'quantity': 3.0, 'price': 42.0, 'discount': 8.0, 'stock': 59.0}}
# item added successfully
# enter the food_id which you want to update2
# Enter the name data you want to update :vada
# Enter the quantity data you want to update :44
# Enter the price data you want to update :48
# Enter the discount data you want to update :4
# Enter the stock data you want to update :120
# {1: {'name': 'pizza', 'quantity': 1.0, 'price': 150.0, 'discount': 20.0, 'stock': 25.0}, 2: {'name': 'vada', 'quantity': '44', 'price': '48', 'discount': '4', 'stock': '120'}}
# enter the food_id which you want to delete2
# Remaing menu are {1: {'name': 'pizza', 'quantity': 1.0, 'price': 150.0, 'discount': 20.0, 'stock': 25.0}}
